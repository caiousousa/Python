# %%
from shutil import posix

from scipy.stats import poisson

# %%
# média de acidentes por dia = 2

# %%
# Probabilidade de 3 carros no dia
poisson.pmf(3,2)
# Out:
# np.float64(0.18044704431548356)

# %%
# Probabilidade de 3 ou menos no dia
poisson.cdf(3,2)
# Out:
# np.float64(0.857123460498547)

# %%
# Probabilidade de mais de 3 no dia
poisson.sf(3,2)
# Out:
# np.float64(0.14287653950145296)
