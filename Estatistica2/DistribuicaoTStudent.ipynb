# %%
from scipy.stats import t

# %%
# média de salários dos cientistas de dados = R$ 75,00 hora. Amostra com 9 funcionários e DP=10

# %%
# Probabilidade de selecionar um cientista com salario menor que 80 reais hora

t.cdf(1.5,8)
# Out:
# np.float64(0.9139983540240443)

# %%
# Probabilidade do salário ser maior que 80 reais por hora
t.sf(1.5,8)
# Out:
# np.float64(0.08600164597595565)

# %%
#Conferindo o espaço amostral =1
t.cdf(1.5,8) + t.sf(1.5,8)
# Out:
# np.float64(0.9999999999999999)
