# %%
import pandas as pd
from scipy import stats
import statsmodels.api as sm
from statsmodels.formula.api import ols
from statsmodels.stats.multicomp import MultiComparison

# %%
tratamento = pd.read_csv(r"C:\Users\caioe\OneDrive\Desktop\Curso Ciência de Dados\19.Estatística II - Prática em Python\anova.csv",sep=';')
tratamento.head()
# Out:
#   Sexo Remedio  Horas
# 0    F       A      5
# 1    F       A     10
# 2    F       A      7
# 3    F       A      7
# 4    M       A      7

# %%
# Boxplot agrupando os dados do remédio
tratamento.boxplot(by = 'Remedio', grid = False)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[7], line 2
#       1 # Boxplot agrupando os dados do remédio
# ----> 2 tratamento.boxplot(by = 'Remedio', grid = False)
#
# File ~\OneDrive\Desktop\Python\.venv\Lib\site-packages\pandas\plotting\_core.py:532, in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, backend, **kwargs)
#     516 @Substitution(data="", backend=_backend_doc)
#     517 @Appender(_boxplot_doc)
#     518 def boxplot_frame(
#    (...)    530     **kwargs,
#     531 ):
# --> 532     plot_backend = _get_plot_backend(backend)
#     533     return plot_backend.boxplot_frame(
#     534         self,
#     535         column=column,
#    (...)    544         **kwargs,
#     545     )
#
# File ~\OneDrive\Desktop\Python\.venv\Lib\site-packages\pandas\plotting\_core.py:1944, in _get_plot_backend(backend)
#    1941 if backend_str in _backends:
#    1942     return _backends[backend_str]
# -> 1944 module = _load_backend(backend_str)
#    1945 _backends[backend_str] = module
#    1946 return module
#
# File ~\OneDrive\Desktop\Python\.venv\Lib\site-packages\pandas\plotting\_core.py:1874, in _load_backend(backend)
#    1872         module = importlib.import_module("pandas.plotting._matplotlib")
#    1873     except ImportError:
# -> 1874         raise ImportError(
#    1875             "matplotlib is required for plotting when the "
#    1876             'default backend "matplotlib" is selected.'
#    1877         ) from None
#    1878     return module
#    1880 found_backend = False
#
# ImportError: matplotlib is required for plotting when the default backend "matplotlib" is selected.
