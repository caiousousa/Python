# %%
from scipy.stats import binom

# %%
#Jogar uma moeda 5 vezes, prob de dar cara 3 vezes
prob = binom.pmf(3,5,0.5)
prob * 100
#31.24%
# Out:
# np.float64(31.24999999999998)

# %%
#Passar quatro sinais de 4 tempos, prob de pegar sinal verde em nenhum sinal
binom.pmf(0,4,0.5) *100
#6.25%
# Out:
# np.float64(6.250000000000003)

# %%
binom.cdf(4,4,0.25)
# Out:
# np.float64(1.0)

# %%
#Probabilidade acumulativa
binom.cdf(4,4,0.25)
# Out:
# np.float64(1.0)

# %%
#Concurso com 12 questões, prob de acertar 7 questões cada uma com 4 alternativa
binom.pmf(7,12,0.25) *100
#1.14%
# Out:
# np.float64(1.1471271514892587)

# %%
binom.pmf(12,12,0.25) *100
# +- 5.96e-06
# Out:
# np.float64(5.9604644775390625e-06)
